# %%
Library_total_books = 20

print(f"Total Number of Books in Library : {Library_total_books}")

Library_records = {
    "101" : ["OS" , "DSA" , "DELD"] ,
    "102" : ["OS" , "OOP"] , 
    "103" : ["OOP" , "DSA" , "OS" , "DELD"] ,
    "104" : ["OOP" , "OS" ] ,
    "105" : ["DSA" , "OOP" , "OS"] ,
    "106" : []
}

Library_total_borrowed_books = 0

for books in Library_records.values():
    Library_total_borrowed_books = len(books) + Library_total_borrowed_books

print(f"Total Number of Books Borrowed : {Library_total_borrowed_books}")

Library_total_members = len(Library_records.keys())

print(f"Total Number of Members in Library : {Library_total_members}")

print("")

Library_borrowed_books_average = Library_total_borrowed_books/Library_total_members

print(f"Average number of books borrowed by all library members : {Library_borrowed_books_average}")

print("")

Borrowed_OS_books = 0
for books in Library_records.values():
    Borrowed_OS_books = books.count("OS") + Borrowed_OS_books
print(f"Total OS Books Borrowed : {Borrowed_OS_books}")

Borrowed_DSA_books = 0
for books in Library_records.values():
    Borrowed_DSA_books = books.count("DSA") + Borrowed_DSA_books
print(f"Total DSA Books Borrowed : {Borrowed_DSA_books}")

Borrowed_OOP_books = 0
for books in Library_records.values():
    Borrowed_OOP_books = books.count("OOP") + Borrowed_OOP_books
print(f"Total OOP Books Borrowed : {Borrowed_OOP_books}")

Borrowed_DELD_books = 0
for books in Library_records.values():
    Borrowed_DELD_books = books.count("DELD") + Borrowed_DELD_books
print(f"Total DELD Books Borrowed : {Borrowed_DELD_books}")

print("")

"""
if(Borrowed_OS_books >= Borrowed_DSA_books):
    if(Borrowed_OS_books >= Borrowed_OOP_books):
        if(Borrowed_OS_books >= Borrowed_DELD_books):
            print("Highest Borrowed book is OS")
        else:
            print("Highest Borrowed book is DELD")
    elif(Borrowed_OOP_books >= Borrowed_DELD_books):
        print("Highest Borrowed book is OOP")
    else:
        print("Highest Borrowed book is DELD")
        
elif(Borrowed_DSA_books >= Borrowed_OS_books):
    if(Borrowed_DSA_books >= Borrowed_OOP_books):
        if(Borrowed_DSA_books >= Borrowed_DELD_books):
            print("Highest Borrowed book is DSA")
        else:
            print("Highest Borrowed book is DELD")
    elif(Borrowed_OOP_books >= Borrowed_DELD_books):
        print("Highest Borrowed book is OOP")
    else:
        print("Highest Borrowed book is DELD")

elif(Borrowed_OOP_books >= Borrowed_OS_books):
    if(Borrowed_OOP_books >= Borrowed_DSA_books):
        if(Borrowed_OOP_books >= Borrowed_DELD_books):
            print("Highest Borrowed book is OOP")
        else:
            print("Highest Borrowed book is DELD")
    elif(Borrowed_DSA_books >= Borrowed_DELD_books):
        print("Highest Borrowed book is DSA")
    else:
        print("Highest Borrowed book is OOP")

elif(Borrowed_DELD_books >= Borrowed_OS_books):
    if(Borrowed_DELD_books >= Borrowed_OOP_books):
        if(Borrowed_DELD_books >= Borrowed_DSA_books):
            print("Highest Borrowed book is DELD")
        else:
            print("Highest Borrowed book is DSA")
    elif(Borrowed_OOP_books >= Borrowed_DSA_books):
        print("Highest Borrowed book is OOP")
    else:
        print("Highest Borrowed book is DSA")

"""

Library_borrowed_books = [ Borrowed_OS_books , Borrowed_DSA_books , Borrowed_OOP_books , Borrowed_DELD_books ]
max_index = ["OS" , "DSA" , "OOP" , "DELD"]

Library_highest_borrowed_book = Library_borrowed_books.index(max(Library_borrowed_books))

print(f"Highest Borrowed book is : {max_index[Library_highest_borrowed_book]}")

Library_borrowed_books = [ Borrowed_OS_books , Borrowed_DSA_books , Borrowed_OOP_books , Borrowed_DELD_books ]
min_index = ["OS" , "DSA" , "OOP" , "DELD"]

Library_lowest_borrowed_book = Library_borrowed_books.index(min(Library_borrowed_books))

print(f"Lowest Borrowed book is : {min_index[Library_lowest_borrowed_book]}")

print("")

"""
for member_id ,books in Library_records.items():
    if(len(books) ==0):
        print(f"{member_id} has borrowed zero books")
"""
Members_not_borrowed = 0
for books in Library_records.values():
    if(len(books) == 0):
        Members_not_borrowed = Members_not_borrowed + 1 

print(f"Number of Members who have not borrowed any book : {Members_not_borrowed}")

print("")

print(f"Most Frequently Borrowed Book is : {max_index[Library_highest_borrowed_book]}")
# Out:
# Total Number of Books in Library : 20
# Total Number of Books Borrowed : 14
# Total Number of Members in Library : 6
#
# Average number of books borrowed by all library members : 2.3333333333333335
#
# Total OS Books Borrowed : 5
# Total DSA Books Borrowed : 3
# Total OOP Books Borrowed : 4
# Total DELD Books Borrowed : 2
#
# Highest Borrowed book is : OS
# Lowest Borrowed book is : DELD
#
# Number of Members who have not borrowed any book : 1
#
# Most Frequently Borrowed Book is : OS
